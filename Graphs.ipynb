# %%
import pandas as pd

#url_csv = "https://raw.githubusercontent.com/veronicafakhri/REME/refs/heads/main/snb-data-snboffzisa-fr-selection-20260223_0900.csv"
url_csv = "https://raw.githubusercontent.com/veronicafakhri/REME/refs/heads/main/snb-data-BSTA@SNB.MONA_US.BIL.AKT.HYP-fr-selection-20260223_0949.csv"



df = pd.read_csv(url_csv, delimiter = ';', skiprows = 2)

df.head(10)
# Out:
#       Date KONSOLIDIERUNGSSTUFE INLANDAUSLAND WAEHRUNG SEKTORESVG  \
# 0  2008-12                    U             I      CHF        PHA
# 1  2009-01                    U             I      CHF        PHA
# 2  2009-02                    U             I      CHF        PHA
# 3  2009-03                    U             I      CHF        PHA
# 4  2009-04                    U             I      CHF        PHA
# 5  2009-05                    U             I      CHF        PHA
# 6  2009-06                    U             I      CHF        PHA
# 7  2009-07                    U             I      CHF        PHA
# 8  2009-08                    U             I      CHF        PHA
# 9  2009-09                    U             I      CHF        PHA
#
#   BANKENGRUPPE        Value
# 0          A40  498534000.0
# 1          A40  500447000.0
# 2          A40  501480000.0
# 3          A40  503305000.0
# 4          A40  505126000.0
# 5          A40  506885000.0
# 6          A40  510160000.0
# ...
